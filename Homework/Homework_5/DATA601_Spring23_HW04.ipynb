# %% [markdown]
# <a href="https://colab.research.google.com/github.com/fgonzaleumbc/DATA601/tree/main/Homework/Homework_5" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## DATA601 - Spring 2023
# ### Homework Assignment 4
# Due date: April 24, 2023 11:59:59pm

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <b>Introduction:</b>
#
# Download this zip file and extract it.
# https://github.com/fgonzaleumbc/DATA601/blob/main/Homework/Homework_5/input_data/DeviceData.zip
#
# Make sure that your notebook and CSV files are under the same folder. There are 150 csv files. In each csv file, there are two columns: frequency (f) and efficiency (Q). First column is same in all the csv files.
#
# The name of the files gives the device parameters. For example,
# "Aphi_AirClad_H410RW855_PulleyCurved_Lc5_G100_W550_Mode1.csv" means that
# - H = 410
# - RW = 855
# - Lc = 5
# - G = 100
# - W = 510

# %% [markdown]
# <b> Question 1 (60 points) </b> Use pandas to read these csv files with a for loop, create a dataframe called "device_performances", which lists first the device parameters (RW, Lc, G, W) and then all the Q values for each frequncy (from 1800 to 5000 at the steps of 5)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Your answer is here

# %% [markdown]
# <b> Question 2 (30 points) </b> <br>
# a. Determine the shape of your dataframe <br>
# b. Check the first and last rows. <br>
# c. Determine the basics statistics (mean, min, max, etc.) <br>
# c. Remove the columns if they are all empty (or NaN)  <br>
# d. Save your dataframe as a csv file.

# %%
# Your answer is here 
# a.

# %%
# Your answer is here 
# b.

# %%
# Your answer is here 
# c.

# %%
# Your answer is here 
# d.

# %% [markdown]
# <b> Question 3 (10 Points) </b> Read the csv file you created in the previous question again using pandas.
# Either using melt or stuck, create a new dataframe which list device parameters (RW, Lc, G, W), frequency, and quantum efficiency in the following format.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Your answer is here

# %% [markdown]
# # NOTEBOOK END
