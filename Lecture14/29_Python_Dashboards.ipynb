# %% [markdown]
# <div class="alert alert-block alert-info">
# Notebook Author:<br>Felix Gonzalez, P.E. <br> Adjunct Instructor, <br> Division of Professional Studies <br> Computer Science and Electrical Engineering <br> University of Maryland Baltimore County <br> fgonzale@umbc.edu
# </div>

# %% [markdown]
# The objective of this Jupyter Notebook is to introduce the topic of dashboarding and discuss various libraries and frameworks available that allow a data scientist to dynamically interact with data and in the best case allow deployment of a dashboard so that other stakeholders can interact with the dataset.

# %%
# Note that if you installed Anaconda at the beginning of Fall 2024 Semester you may encounter an issue with 
# Running a widget and the output displaying "Error displaying widget".
# To solve install a later version.
#pip install ipywidgets==8.0.4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

import ipywidgets as widgets
from IPython.display import Image, display, HTML, clear_output
from ipywidgets import interact, interact_manual

# %% [markdown]
# # Table of Contents
#
# [Data Visualization and Exploratory Data Analysis](#Data-Visualization-and-Exploratory-Data-Analysis)
#
# [Python Dashboards](#Python-Dashboards)
#
# - [Jupyter Notebook Widgets](#Jupyter-Notebook-Widgets)
#
# - [Anaconda Panel, Bokeh and Plotly Dash](#Anaconda-Panel,-Bokeh-and-Plotly-Dash)
#
# - [Comparison of Different Dashboard Libraries](#Comparison-of-Different-Dashboard-Libraries)
#
# - [Other Python Libraries that Could be Used for Dashboards and Application Development](#Other-Python-Libraries-that-Could-be-Used-for-Dashboards-and-Application-Development)
#
# [IPYWidgets Introduction](#IPYWidgets-Introduction)
#
# - [Building a widget](#Building-a-widget)
#
# - [Building Complex Widgets](#Building-Complex-Widgets)
#
# [Example Data: Movie Dataset](#Example-Data:-Movie-Dataset)
#
# [Example Dashboard: IPY Widgets](#Example-Dashboard:-IPY-Widgets)
#
# - [Unique values of dropdown menus](#Unique-values-of-dropdown-menus)
#
# - [Filter and Plot Function](#Filter-and-Plot-Function)
#
# - [Main Widget Filtering](#Main-Widget-Filtering)
#
# [Example Dashboard: Bokeh](#Example-Dashboard:-Bokeh)
#
# [Example Dashboard: Data Science Example Folder](#Example-Dashboard:-Data-Science-Example-Folder)
#
# [Example: Streamlit](#Example:-Streamlit)
#
# [Other Examples: Geospatial  Analysis and Spatial Visualization](#Other-Examples:-Geospatial-Analysis-and-Spatial-Visualization)

# %% [markdown]
# # Data Visualization and Exploratory Data Analysis
# [Table of Contents](#Table-of-Contents)
#
# After data cleaning, a data scientist will typically perform an exploratory data analysis where they explore relationships between the features to obtain insights, and evaluate trends. During this stage, the data scientist also explore various visualizations that may provide insights. Once important tables and visualizations are identified the data scientist may use these as part of their analysis in a report where the results are communicated. The data scientist may also identify some tables or visualizations that should be deployed as a dashboard and allow interacting with the dataset.

# %% [markdown]
# # Python Dashboards
# [Table of Contents](#Table-of-Contents)
#
# Python has various libraries that allow for creation of dashboards. In the simpler form a dashboard can be developed using [Jupyter Notebook Widgets](https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html). Python has various other libraries used for developing dashboards. These include [Anaconda Panel](https://panel.holoviz.org/), [Plotly Dash](https://dash.plotly.com/) , [Streamlit](https://streamlit.io/), [Voila](https://voila-gallery.org/) among others Python dashboard libraries. [Amazon Web Services](https://aws.amazon.com/free/analytics/), [Microsoft Azure](https://azure.microsoft.com/en-us/products/synapse-analytics/), [Google Cloud Platform](https://cloud.google.com/solutions/marketing-analytics/), [Microstrategy](https://www.microstrategy.com/en), [Palantir Foundry](https://www.palantir.com/), [Tableau](https://www.tableau.com/), among others, are other commercially available platforms that have their own analytics and artificial intelligence solutions that also allow for developing data analysis dashboard applications. Most of these platforms also have the capability to deploy Python code in one way or another.
#
# There are four libraries that can be used to create dashboard applications and are [Included with Anaconda Distribution](https://docs.anaconda.com/free/anaconda/reference/packages/pkg-docs/). These are discussed in the following sections and include:
# - Jupyter Notebook Widgets
# - Anaconda Panel
# - Bokeh
# - Plotly Dash
#
# The creation of the dashboard allows interacting dinamyically with data rather than relying on code to apply filters or calling functions to perform some analysis. A dashboard allows to more efficiently interact with the data and find insights and patters accross various filters and multiple features. The process followed is the sama as discussed in the class. The data will go through some form of cleaining, preparation and transformation. Data visualization and exploratory data analysis will help in identifying what plots, tables and outputs dashboard should show.

# %% [markdown]
# #### Jupyter Notebook Widgets
# [Table of Contents](#Table-of-Contents)
#
# [Jupyter Notebook Widgets, IPY Widgets](https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html) allow a user to quickly develop interactivity between the data and a simple user interface that runs in Jupyter Notebooks. There are various widgets that are designed to work with various data types (e.g., floats, integers, categorical data). These include but is not limted to sliders (e.g., float, integer), drop down menus, multiple selection menus, radio buttons, check box among many other.
#
# The IPY Widgets have one advantage in that they can be quickly developed and run in a Jupyter Notebook and allows a data scientist to develop a concept and explore potential capabilities of a dashboard while also allowing to identify early limitations of the data and the tools without spending the resources in developing a web-based dashboard that needs to be hosted and deployed (e.g., website). However, the main disadvantage of Jupyter Notebook Widgets is that it cannot be deployed in a website framework or an application and will need to be moved to another library and platform if a stakeholders need access.
#
# The other libraries that are discussed have different advanatages and limitations that need to be evaluated separately depending on the needs of the analysis, stakeholders and the organization.

# %% [markdown]
# #### Anaconda Panel, Bokeh and Plotly Dash
# [Table of Contents](#Table-of-Contents)
#
#
# Similarly to the IPYWidgets, Anaconda Panel, Bokeh and Plotly Dash are libraries that let you create custom and interactive dashboards, applications, widgets. These can be used to show data filtering and analysis outputs that may include but is not limited to tables, plots, images, text, and other objects. Like all libraries, each of this libraries also has its learning curve.
#
# __[Anaconda Panel](https://panel.holoviz.org/)__ "is an open-source Python library that lets you create custom interactive web apps and dashboards by connecting user-defined widgets to plots, images, tables, or text" (Description from website). Anaconda Panel gallery can be found at https://panel.holoviz.org/gallery/index.html. The following article provides an overview of Anaconda Panel and some examples https://medium.com/@philipp.jfr/panel-announcement-2107c2b15f52.
#
# __[Bokeh](https://bokeh.org/)__ "is a Python library for creating interactive visualizations for modern web browsers. It helps you build beautiful graphics, ranging from simple plots to complex dashboards with streaming datasets. With Bokeh, you can create JavaScript-powered visualizations without writing any JavaScript yourself" (Description from website). Example Bokeh dashboard can be found at: https://demo.bokeh.org.
#
# __[Plotly Dash](https://dash.plotly.com/)__ "is the original low-code framework for rapidly building data apps in Python"  (Description from website).
#
#
# #### Comparison of Different Dashboard Libraries
# [Table of Contents](#Table-of-Contents)
#
# Each of the libraries above have their featutes advantages, disadvantages and limitations. The following articles compare these libraries and provides some thoughts on when to use one dashboard library over the other. Note that the libraries continue to be developed and features can be added that improve the usability.
#
# - https://panel.holoviz.org/about/comparisons.html
# - https://quansight.com/post/dash-voila-panel-streamlit-our-thoughts-on-the-big-four-dashboarding-tools
# - https://medium.com/spatial-data-science/the-best-tools-for-dashboarding-in-python-b22975cb4b83
# - https://medium.datadriveninvestor.com/streamlit-vs-dash-vs-voil%C3%A0-vs-panel-battle-of-the-python-dashboarding-giants-177c40b9ea57

# %% [markdown]
# #### Other Python Libraries that Could be Used for Dashboards and Application Development
# [Table of Contents](#Table-of-Contents)
#
#
# Python also has various other libraries that can help you create applications (e.g., web- and desktop-applications). __[Tkinter](https://docs.python.org/3/library/tkinter.html)__ is a library included with base Python that allows to develop graphical user interface in a desktop applications. The Tkinter desktop application can be exported with an installer such as [PYInstaller](https://pypi.org/project/pyinstaller/) to be shared and used by thsoe who do not have Python and its dependencies installed. However, sharing apps this way may not be optimal and may have its own sets of challenges.
#
# Similar to Tkinter, __[PyQT](https://pypi.org/project/PyQt5/)__ allows development of graphical user interface and is cross platform including desktop and mobile applications.
#
# __[Flask](https://pypi.org/project/Flask/)__ and __[DJANGO](https://www.djangoproject.com/)__ are web frameworks that can be used to create websites. However, in both cases, the developer will need to be familiar with other web langauges such as HTML, CSS, JS, etc. depending on the complexity of the website being designed.
#
# #### Dashboard Library References NOT Included in Anaconda Distribution:
#
# Other dashboard development libraries that are not included in the anaconda distribution includes but is not limited to [Voila](https://pypi.org/project/voila/), [Streamlit](https://pypi.org/project/streamlit/), [JSD3](https://d3js.org/) among many others.

# %% [markdown]
# # IPYWidgets Introduction
# [Table of Contents](#Table-of-Contents)
#
# [Jupyter Notebook Widgets, IPY Widgets](https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html) has several widgets that can be used in the dashboard to apply filters and create dynamic experience. Most common widgets include:
#
# - Slider (IntSlider or FloatSlider)
# - Range Slider (IntRangeSlider or FloatRangeSlider)
# - Checkbox
# - RadioButtons
# - Dropdown Menus
# - Select Menu
# - Multiple Select Menu (SelectMultiple)
# - Text Box
# - Date picker
#
# IPY Widgets allow to have children or [Nesting Tabs and Accordions](https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html#nesting-tabs-and-accordions) tabs within a widget. This allows to create more complex dashboards within the same widget. This notebook will not provide examples of nested tabs but the 7_Data_Analysis_Dashboards.ipynb from the Data Science Example folder has various nested widgets.
#
# The following cell provides examples of some of the common widgets.

# %%
# https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html#intslider
widgets.IntSlider(value=5,
                  min=0,
                  max=10,
                  step=1,
                  description='Integer Slider:',
                  disabled=False,
                  continuous_update=False,
                  orientation='horizontal',
                  readout=True,
                  readout_format='d')
# Out:
# IntSlider(value=5, continuous_update=False, description='Integer Slider:', max=10)

# %%
# https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html#intrangeslider
widgets.IntRangeSlider(value=[2, 8],
                       min=0,
                       max=10,
                       step=1,
                       description='Range Slider:',
                       disabled=False,
                       continuous_update=False,
                       orientation='horizontal',
                       readout=True,
                       readout_format='d')
# Out:
# IntRangeSlider(value=(2, 8), continuous_update=False, description='Range Slider:', max=10)

# %%
# https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html#checkbox
widgets.Checkbox(value=False,
                 description='Check Box',
                 disabled=False,
                 indent=False)
# Out:
# Checkbox(value=False, description='Check Box', indent=False)

# %%
# https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html#dropdown
widgets.Dropdown(
    options=[('One', 1), ('Two', 2), ('Three', 3)],
    value=2,
    description='Number:',
)
# Out:
# Dropdown(description='Number:', index=1, options=(('One', 1), ('Two', 2), ('Three', 3)), value=2)

# %%
# https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html#radiobuttons
widgets.RadioButtons(options=['Apple', 'Banana', 'Orange'],
                     description='Fruits',
                     disabled=False
                    )
# Out:
# RadioButtons(description='Fruits', options=('Apple', 'Banana', 'Orange'), value='Apple')

# %%
# https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html#selectmultiple
widgets.SelectMultiple(options=['Apple', 'Banana', 'Orange', 'Pineapple'],
                       value=['Banana'],
                       #rows=10,
                       description='Fruits',
                       disabled=False
                      )
# Out:
# SelectMultiple(description='Fruits', index=(1,), options=('Apple', 'Banana', 'Orange', 'Pineapple'), value=('B…

# %%
# https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html#text
widgets.Text(value='',
             placeholder='Type Something',
             description='Input Text Box:',
             disabled=False,
             style={'description_width': 'initial'}, 
             layout = widgets.Layout(width='50%')
            )
# Out:
# Text(value='', description='Input Text Box:', layout=Layout(width='50%'), placeholder='Type Something', style=…

# %%
# https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html#text
widgets.DatePicker(description='Date',
                   disabled=False)
# Out:
# DatePicker(value=None, description='Date', step=1)

# %% [markdown]
# #### Building a widget
# [Table of Contents](#Table-of-Contents)
#
# There are multiple ways to build and run widgets. Two main elements is the interact_manual and the interact functions. The  "interact_manual" creates a "Run Interact" button and does not run the specified functions until the button is selected. The  "interact" updates the function as we make changes in the widget selection. There are other elements that may be optional such as defining a variable name or the way that the functions are built and called.
#
# In this example we will create a function that takes in an input text and prints a line with some other text and the input text. One exmaple with the interact_manual and the same example with the interact. Note that for functions that take some time to run you want to use the "interact_manual" as making small changes in the "interact" make result in freezing or having to wait the processor to solve the functions.
#
# In general building a widget follows this steps.
# 1. Define funcitons you will be using or want to run (e.g., filter data, calculation, etc) with the input parameters that you will feed into the function.
# 2. Use either interact_manual or interact function to define the app variable
#     a. Call the defined function in the first parameter
#     b. Define which widget the function will use as inputs.
#     c. Define parameters for each widget.
#
# Documentation References:
#
# - [Widget Basics](https://ipywidgets.readthedocs.io/en/stable/examples/Widget%20List.html)
# - [Using Interact Method vlatest](https://ipywidgets.readthedocs.io/en/latest/examples/Using%20Interact.html)
# - [Using Interact Method v7.6.2](https://ipywidgets.readthedocs.io/en/7.6.2/examples/Using%20Interact.html)

# %%
def print_data(text_to_print):
    print(f'The text that you want to print is: "{text_to_print}"')
    #text_variable = text_to_print

# %%
# The interact manual does not call the function and applies the input parameters until "Run Interact" button is selected.
interact_manual(print_data,
                text_to_print = widgets.Text(value='',
                                             placeholder='Type Something',
                                             description='Input Text Box:',
                                             disabled=False,
                                             style={'description_width': 'initial'}, 
                                             layout = widgets.Layout(width='50%'),
                                             continuous_update=False));
# Out:
# C:\Users\felix\AppData\Local\Temp\ipykernel_36584\325530986.py:2: DeprecationWarning: on_submit is deprecated. Instead, set the .continuous_update attribute to False and observe the value changing with: mywidget.observe(callback, 'value').
#   interact_manual(print_data,
# interactive(children=(Text(value='', continuous_update=False, description='Input Text Box:', layout=Layout(wid…

# %%
# We can also define the interact_manual or interact as a variable.
print_app = interact_manual(print_data,
                            text_to_print = widgets.Text(value='',
                                                         placeholder='Type Something',
                                                         description='Input Text Box:',
                                                         disabled=False,
                                                         style={'description_width': 'initial'}, 
                                                         layout = widgets.Layout(width='50%')));
# Out:
# C:\Users\felix\AppData\Local\Temp\ipykernel_36584\3030707438.py:2: DeprecationWarning: on_submit is deprecated. Instead, set the .continuous_update attribute to False and observe the value changing with: mywidget.observe(callback, 'value').
#   print_app = interact_manual(print_data,
# interactive(children=(Text(value='', description='Input Text Box:', layout=Layout(width='50%'), placeholder='T…

# %%
# Note that the interact will show the changes interactively.
print_app_dynamic = interact(print_data,
                             text_to_print = widgets.Text(value='',
                                                          placeholder='Type Something',
                                                          description='Input Text Box:',
                                                          disabled=False,
                                                          style={'description_width': 'initial'}, 
                                                          layout = widgets.Layout(width='50%')))
# Out:
# interactive(children=(Text(value='', description='Input Text Box:', layout=Layout(width='50%'), placeholder='T…

# %%
# The interact without continuous update.
# Does not call the function and applies the input parameters until "Return" key selection.
interact(print_data,
         text_to_print = widgets.Text(value='',
                                      placeholder='Type Something',
                                      description='Input Text Box:',
                                      disabled=False,
                                      style={'description_width': 'initial'}, 
                                      layout = widgets.Layout(width='50%'),
                                      continuous_update=False));
# Out:
# interactive(children=(Text(value='', continuous_update=False, description='Input Text Box:', layout=Layout(wid…

# %% [markdown]
# #### Building Complex Widgets
# [Table of Contents](#Table-of-Contents)
#
# When building a complex widget, I typically create a main function that filters the data and then call other functions depending on what selection I make in the initial widget options or using children widget pages or tabs. Let's explore in the next section how to build a widget to filter data and plot features.
#
# The 7_Data_Analysis_Dashboards.ipynb from the Data Science Example folder provides a very complex example of how widgets children or nested widgets looks like. That notebook widgets include data visualization, natural language processing, text clustering and other complex examples all in the same widget at the cost of hundreds to thousands of lines of code.

# %% [markdown]
# # Example Data: Movie Dataset
# [Table of Contents](#Table-of-Contents)
#
# Recall that in the Data Science Example folder we had an example were we used IMDB movie dataset (see notebook for details) and showed the steps for cleaning, preparing and transforming the data as (i.e., see notebook 1_Data_Cleaning_Template.ipynb). The examples from here on will use the cleaned data output of that Jupyter Noteook.

# %%
# LOADING CSV FILE DATA
df_data = pd.read_csv('https://raw.githubusercontent.com/fgonzaleumbc/DATA601/main/Data_Science_Example/output_data/df_data_clean.csv', 
                      encoding = "utf-8-sig",
                      parse_dates=['release_date'],
                      keep_default_na=False,
                      na_values=['', '-1.#IND', '1.#QNAN', '1.#IND', '-1.#QNAN', '#N/A','N/A', '#NA', 'NULL', 'NaN', '-NaN', 'nan', '-nan'])

# %%
df_data.head(3)
# Out:
#      budget                                             genres     id  \
# 0   2600000  [{"id": 16, "name": "Animation"}, {"id": 10751...  10895
# 1  92620000  [{"id": 18, "name": "Drama"}, {"id": 878, "nam...     19
# 2   8250000  [{"id": 18, "name": "Drama"}, {"id": 36, "name...  11620
#
#   original_language original_title  \
# 0                en      Pinocchio
# 1                de     Metropolis
# 2                en      Quo Vadis
#
#                                             overview  popularity  \
# 0  Lonely toymaker Geppetto has his wishes answer...   46.007991
# 1  In a futuristic city sharply divided between t...   32.351527
# 2  Set against the back drop of Rome in crisis, G...    7.973109
#
#                                 production_companies  \
# 0  [{"name": "RKO Radio Pictures", "id": 6}, {"na...
# 1  [{"name": "Paramount Pictures", "id": 4}, {"na...
# 2  [{"name": "Metro-Goldwyn-Mayer (MGM)", "id": 8...
#
# ...

# %%
# Let's explore the info of the data.
# Note that this data should be cleaned already and should have very few issues if any.
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3225 entries, 0 to 3224
# Data columns (total 46 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   budget                   3225 non-null   int64
#  1   genres                   3225 non-null   object
#  2   id                       3225 non-null   int64
#  3   original_language        3225 non-null   object
#  4   original_title           3225 non-null   object
#  5   overview                 3225 non-null   object
#  6   popularity               3225 non-null   float64
#  7   production_companies     3225 non-null   object
#  8   production_countries     3225 non-null   object
#  9   release_date             3225 non-null   datetime64[ns]
#  10  revenue                  3225 non-null   int64
#  11  runtime                  3225 non-null   int64
#  12  spoken_languages         3225 non-null   object
#  13  vote_average             3225 non-null   float64
# ...

# %%
# Column selection for selecting columsn in loops used in the data cleaning, visualization and model functions below.
dfcolumns = list(df_data.columns.values)
dfcolumns_index = pd.DataFrame(dfcolumns, columns=['column'])
dfcolumns_index.head()
# Out:
#               column
# 0             budget
# 1             genres
# 2                 id
# 3  original_language
# 4     original_title

# %%
# In the 2_Exploratory_Data_Analysis.ipynb we use the sns.pairplot() function to explore the scatter plot of a few features.
# We can use this scatter plots to decide which plots to use in our data dashboard.
# Selecting columns to plot.
cols_to_plot = ['budget', 'popularity', 'revenue', 'runtime', 
                'vote_average', 'vote_count',
                'release_cy', 
                'box_office_earning', 'revenue_budget_ratio', 
                'overview_char_count', 'overview_word_count']
# SNS Pairplot Function
sns.pairplot(df_data[cols_to_plot].sample(200), 
             corner = True, 
             kind = 'scatter',
             height = 2.5);

# %%
# Lets select and do a plot for the box_office_earning in the x-axis and the runtime in the y-axis.

# %%
plt.scatter(x = df_data['box_office_earning'], 
            y = df_data['runtime'], 
            alpha = 0.25)
plt.show()

# %% [markdown]
# # Example Dashboard: IPY Widgets
# [Table of Contents](#Table-of-Contents)
#
# Let's create a widget that allows filtering of the data and dynamically change the scatter plot of box_office_earning vs. runtime. The widget should have two funcitons. One that is used to first filter the data. The other to create the scatter plot.
#
# We will first create a filter that allows selecting the following features:
# - Vote Count
# - Box Office Earnings
# - Release Calendar Year
# - Genres
#
# Note that in some filters above (e.g., release calendar year and genres) have a defined set of options. Before we create anything we need to create a list of each of the options.
#
# We then need to define the function that uses the widget's input parameters to filter and plot the data.
#
# The main widget is defined at the end as the dashboard is created just below it.

# %% [markdown]
# #### Unique values of dropdown menus
# [Table of Contents](#Table-of-Contents)

# %%
# List of the Release Calendar Years
release_cy_list = (df_data['release_cy'].unique()).tolist() # Extract unique calendar year values.
release_cy_list.sort() # Sorts the release calendar year values
#release_cy_list = ['NaT']+release_cy_list # Includes 'NaT'. Only needed if data has undefined year.
#print(release_cy_list)

# %%
# Develops a unique list of genres to be able to use it in the menus.
# Note that this is using the one-hot-encoded Genres column features to extract the options.

# First and Last index of the Movie Genres. 
# Two methods: First using the columns of the main dataframe, the other of the dfcolumns_index dataframe.
first_genre_index = df_data.columns.to_list().index("Action")
#first_genre_index = dfcolumns_index.index[dfcolumns_index['column'] == str('Action')][0] 

last_genre_index = df_data.columns.to_list().index("Western")
#last_genre_index = dfcolumns_index.index[dfcolumns_index['column'] == str('Western')][0] 

# List of Unique Genres.
genres_list = sorted(dfcolumns_index['column'][first_genre_index:last_genre_index+1].to_list())
#genres_list

# %% [markdown]
# #### Filter and Plot Function
# [Table of Contents](#Table-of-Contents)

# %%
def filter_plot_data(vote_count_filter, box_office_earning_filter, release_cy_filter, genres_filter):
    
    # Filterieng of the data using the functions
    df_data_filtered = df_data.loc[(df_data['vote_count'] >= min(vote_count_filter)) &
                                   (df_data['vote_count'] <= max(vote_count_filter)) &
                                   (df_data['box_office_earning'] >= box_office_earning_filter) &
                                   (df_data['release_cy'] >= min(release_cy_filter)) &
                                   (df_data['release_cy'] <= max(release_cy_filter)) &
                                   (df_data['genres'].str.contains('|'.join(genres_filter), 
                                                                   flags=re.IGNORECASE, regex=True))
                                  ].copy().reset_index(drop = True)
    

    display(HTML(f'<h2>Scatter Plot box_office_earning vs. runtime<h2>'))
    plt.scatter(x = df_data_filtered['box_office_earning'], 
                y = df_data_filtered['runtime'], 
                alpha = 0.25)
    plt.show()
    
    display(HTML(f'<h2>Selected Data Rows:<h2>'))
    print(f'The fitlered data contains {df_data_filtered.shape[0]} rows of data.')
    print(f'The source data has {len(df_data)} records and ONLY {len(df_data_filtered)} records are selected.')
    
    # These lines of code are used to show how each Widget outputs the data.
    display(HTML(f'<h2>These lines of code are used to show how each Widget outputs the data:<h2>'))
    print(f'1. vote_count_filter is submitted as a {type(vote_count_filter)} data type. Selection is: {vote_count_filter}.')
    print(f'2. box_office_earning_filter is submitted as a {type(box_office_earning_filter)} data type. Selection is:  {box_office_earning_filter}.')
    print(f'3. release_cy_filter is submitted as a {type(release_cy_filter)} data type. Selection is: {release_cy_filter}.')
    print(f'4. genres_list is submitted as a {type(genres_filter)} data type. Selection is: {genres_filter}')
    
    display(HTML(f'<h2>NOTES:<h2>'))
    print('When selecting all filters the source data and filtered data shapes do not match.')
    print('This movie can be found in the data science example dashboard by using the NOT and selecting all genres.')
    print('This movie is an example of getting to the dashboard creation and finding an item that could potentially be cleaned out in the data cleaning notebook.')

    # Note that there is one movie that has the Genre's missing and needs to be cleaned out.
    # This movie is an example of getting to the dashboard creating and finding this item to be cleaned.

# %% [markdown]
# #### Main Widget Filtering
# [Table of Contents](#Table-of-Contents)

# %%
# PRIMARY WIDGET FILTER OPTIONS
display(HTML(f'<h3>MAIN FILTER WIDGET<h3>'))
print("NOTE: Caution when selecting filters. Some filters may have overlaps while other filters be mutually exclusive.")

# The Application name may be left as "_" or be called "app" or "my_app".
# Change interact_manual to interact to see the effect.
_ = interact_manual(filter_plot_data, # "filter_data" function filters the data and calls sub-widgest and related functions.
                    vote_count_filter = widgets.IntRangeSlider(value=[0, 20000],
                                                           min = 0,
                                                           max = max(df_data['vote_count'])+1,
                                                           step = 1000,
                                                           description='Vote Count',
                                                           disabled=False,
                                                           continuous_update=False,
                                                           orientation='horizontal',
                                                           readout=True,
                                                           readout_format='d',
                                                           style = {'description_width': 'initial'},
                                                           layout = widgets.Layout(width='50%')),
                    box_office_earning_filter = widgets.IntSlider(value=0,
                                                                   min = 0,
                                                                   max = max(df_data['box_office_earning']),
                                                                   step = 100000,
                                                                   description='Min. Box Office Earning',
                                                                   disabled=False,
                                                                   continuous_update=False,
                                                                   orientation='horizontal',
                                                                   readout=True,
                                                                   readout_format='d',
                                                                   style = {'description_width': 'initial'},
                                                                   layout = widgets.Layout(width='50%')),
                    release_cy_filter = widgets.IntRangeSlider(value=[min(release_cy_list), max(release_cy_list)],
                                                               min=min(release_cy_list),
                                                               max=max(release_cy_list),
                                                               step=1,
                                                               description='Release Calendar Year', disabled=False,
                                                               continuous_update=False,
                                                               orientation='horizontal',
                                                               readout=True,
                                                               readout_format='d',
                                                               style = {'description_width': 'initial'},
                                                               layout = widgets.Layout(width='50%')),
                    genres_filter = widgets.SelectMultiple(options= genres_list,
                                                             value = genres_list,
                                                             rows = 6,
                                                             description = 'Genres', 
                                                             disabled=False, style={'description_width': 'initial'}))
# Out:
# <h3>MAIN FILTER WIDGET<h3>
# NOTE: Caution when selecting filters. Some filters may have overlaps while other filters be mutually exclusive.
# interactive(children=(IntRangeSlider(value=(0, 13753), continuous_update=False, description='Vote Count', layo…

# %% [markdown]
# # Example Dashboard: Bokeh
# [Table of Contents](#Table-of-Contents)
#
# The following example is deployed in the Bokeh website (https://demo.bokeh.org/movies). It also shows a very similar dataset with very similar filters and very similar functionality albeit a different look given it is from different dashboard libraries.
#
# The main advantage of Bokeh over the Jupyter Widgets is that it can be deployed in a website and accessed by the website users where the Jupyter Notebooks Widget have to be shared via sharing the .ipynb file and the person running it needs to have Python and dependencies installed.
#
# Note that these web-based dashboard libraries like Bokeh also show part of the data when hovering over a datapoint. The previous example tries to keep it simple to show how easy it is to develop a dashboard like application. However, the Jupyter Notebook Widgets also allow the same functionality with other more advance plotting libraries like Plotly instead of MatPlotLib.

# %% [markdown]
# # Example Dashboard: Data Science Example Folder
# [Table of Contents](#Table-of-Contents)
#
# Under the Data Science Example Folder, the 7_Data_Analysis_Dashboards.ipynb has examples of various nested and children widgets shown as tabs in the dashboard. The widgets include data visualization, statistics, predictive modeling, natural language processing, word clouds, text clustering, and other complex examples all in the same widget at the cost of hundreds to thousands of lines of code. Not sure what would it take to develop something similar in another library such as Panel, Bokeh, or Dash. In any case it shows the potential how useful a dashboard can be.

# %% [markdown]
# # Example: Streamlit
# [Table of Contents](#Table-of-Contents)
#
# The student grader will provide a short presentation on the Streamlit dashboard library. The files can be found under the Streamlit folder.
# - To install Streamlit, open Anaconda Prompt and type "pip install streamlit"
# - https://pypi.org/project/streamlit/;

# %% [markdown]
# # Other Examples: Geospatial Analysis and Spatial Visualization
# [Table of Contents](#Table-of-Contents)
#
# There are various libraries that support many types of visualizations that can be paired with dashboards. One example not discussed in class include geospatial analysis and visualization. For example, the airline industry dataset that we discussed in class which included airport locations (e.g., longitude and latitude) can be used to create a visualization of a map (i.e., geography) and create a network visualization of the routes and delays overlayed in the map. The following references provide some articles and examples which attempt to do something similar.
# - https://www.kaggle.com/code/mbggbm/flight-routes-spatial-visualization-with-plotly/notebook
# - https://coderzcolumn.com/tutorials/data-science/how-to-create-connection-map-chart-in-python-jupyter-notebook-plotly-and-geopandas
# - https://ipython-books.github.io/142-drawing-flight-routes-with-networkx/

# %% [markdown]
# # NOTEBOOK END
